# %%
# !pip install seaborn

# %%
#import pandas
import pandas as pd

# %%
#import arquivo
df = pd.read_csv('attacks.csv', sep=',', index_col = 0, encoding='latin-1')

# %%
print(df.head())
# Out:
#                     Date    Year        Type    Country             Area  \
# Case Number
# 2018.06.25   25-Jun-2018  2018.0     Boating        USA       California
# 2018.06.18   18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2018.06.09   09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 2018.06.08   08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 2018.06.04   04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                                    Location     Activity             Name  \
# Case Number
# 2018.06.25      Oceanside, San Diego County     Paddling      Julie Wolfe
# 2018.06.18   St. Simon Island, Glynn County     Standing  Adyson McNeely
# 2018.06.09                     Habush, Oahu      Surfing      John Denges
# 2018.06.08               Arrawarra Headland      Surfing             male
# 2018.06.04                         La Ticla  Free diving   Gustavo Ramos
#
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity',
#        'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
#filtrar colunas que vou usar
bite = df[['Year', 'Type', 'Activity', 'Name', 'Age', 'Fatal (Y/N)', 'Species ']]

# %%
bite.head()
# Out:
#                Year        Type     Activity             Name  Age  \
# Case Number
# 2018.06.25   2018.0     Boating     Paddling      Julie Wolfe   57
# 2018.06.18   2018.0  Unprovoked     Standing  Adyson McNeely    11
# 2018.06.09   2018.0     Invalid      Surfing      John Denges   48
# 2018.06.08   2018.0  Unprovoked      Surfing             male  NaN
# 2018.06.04   2018.0    Provoked  Free diving   Gustavo Ramos   NaN
#
#             Fatal (Y/N)         Species
# Case Number
# 2018.06.25            N      White shark
# 2018.06.18            N              NaN
# 2018.06.09            N              NaN
# 2018.06.08            N        2 m shark
# 2018.06.04            N  Tiger shark, 3m

# %%
#remove null values
bite_lite = bite.dropna()

# %%
bite_lite.head()
# Out:
#                 Year        Type        Activity                    Name Age  \
# Case Number
# 2018.06.25    2018.0     Boating        Paddling             Julie Wolfe  57
# 2018.06.03.a  2018.0  Unprovoked        Swimming  Jose Ernesto da Silva   18
# 2018.05.27    2018.0  Unprovoked         Fishing                    male  52
# 2018.05.26.b  2018.0  Unprovoked         Walking               Cody High  15
# 2018.05.24    2018.0    Provoked  Feeding sharks                    male  32
#
#              Fatal (Y/N)         Species
# Case Number
# 2018.06.25             N      White shark
# 2018.06.03.a           Y      Tiger shark
# 2018.05.27             N  Lemon shark, 3'
# 2018.05.26.b           N   Bull shark, 6'
# 2018.05.24             N  Grey reef shark

# %%
#limpar Year column

bite_lite.dropna()

# %%
bite_lite.Year.unique()
# Out:
# array([2018., 2017., 2016., 2015., 2014., 2013., 2012., 2011., 2010.,
#        2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002., 2001.,
#        2000., 1999., 1998., 1997., 1996., 1995., 1994., 1993., 1992.,
#        1991., 1990., 1989., 1988., 1987., 1986., 1985., 1984., 1983.,
#        1982., 1981., 1980., 1979., 1978., 1977., 1976., 1975., 1974.,
#        1973., 1972., 1971., 1970., 1969., 1968., 1967., 1966., 1965.,
#        1964., 1963., 1962., 1961., 1960., 1959., 1958., 1957., 1956.,
#        1955., 1954., 1953., 1952., 1951., 1950., 1949., 1948., 1947.,
#        1946., 1945., 1944., 1943., 1942., 1941., 1940., 1939., 1938.,
#        1937., 1936., 1935., 1934., 1933., 1932., 1931., 1930., 1929.,
#        1928., 1927., 1926., 1925., 1924., 1922., 1919., 1916., 1912.,
#        1906., 1905., 1901., 1899., 1898., 1894., 1892., 1880., 1879.,
#        1878., 1868.,    0.])

# %%
bite_lite.Activity.unique()
# Out:
# array(['Paddling', 'Swimming', 'Fishing', 'Walking', 'Feeding sharks',
#        'Scuba diving', 'Surfing', 'Paddle-skiing', 'Body boarding',
#        'Stand-Up Paddleboarding', 'Wading', 'Scuba Diving',
#        'Cleaning fish', 'Snorkeling', 'Spearfishing', 'Free diving',
#        'Fishing / Wading', 'Night bathing', 'Kayaking / Fishing',
#        'Body surfing', 'SUP', 'Kayaking', 'Surfing ', 'Touching a shark',
#        'Attempting to lasso a shark', 'Washing hands', 'Surf skiing ',
#        'Surf fishing', 'Floating', 'SUP Foil boarding', 'Lobstering',
#        'Kite surfing', 'Floating in tube', 'Standing', 'Diving',
#        'Teasing a shark', 'Paddle boarding', 'Lobster fishing',
#        'Kayak Fishing', 'Surf-skiing', 'Scallop diving on hookah',
#        'Body boarding ', 'Playing in the water', 'Body Boarding',
#        'Boogie boarding', 'Playing', 'Attempting to rescue a shark',
#        'Photographing the shark', 'Standing / Snorkeling',
# ...

# %%
#Definir categorias 

'Paddling',
'Swimming',
'Fishing', 
'Walking', 
'Scuba diving',
'Surfing'
'Snorkeling'
'Floating'
'Kite boarding'
'Diving'

# %%
#limpar coluna de especies

# %%
#limpar coluna de Name

# %%
3 PERGUNTAS:
    
    fin_times
    nomes_fatais
    carne_fresca

# %% [markdown]
# # 1. Como os hobbys dos tubarões tem evoluido ao longo dos anos?

# %% [markdown]
# identificar como cada especie tem interferido em tipos de atividades diferentes ao longo dos anos
#
# simplificar >> atividades x anos

# %%
hobbys = bite[[ "Year", "Activity"]]

# %%
hobbys.head()
# Out:
#                Year     Activity
# Case Number
# 2018.06.25   2018.0     Paddling
# 2018.06.18   2018.0     Standing
# 2018.06.09   2018.0      Surfing
# 2018.06.08   2018.0      Surfing
# 2018.06.04   2018.0  Free diving

# %%
hobbys.groupby(['Year', 'Activity']).count()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %% [markdown]
# # 2. Quais os nomes mais perigosos para entrarem na água?

# %% [markdown]
# identificar tendencias de ataques fatais analisando a primeira letra do primeiro nome dos atacados

# %%
#adicionar coluna de primeira letra do nome

# %% [markdown]
# # 3. Qual o ponto de carne preferida dos tubarões?

# %% [markdown]
# identificar tendencies entre a especie dos tubaroes e a idade dos atacados
#
# simplificar >> group by idade

# %%
#filtrar colunas que vou usar
#bite = df[['Year', 'Type', 'Activity', 'Name', 'Age', 'Fatal (Y/N)', 'Species ']]

carne_fresca = bite[['Age', 'Species ']]

# %%
carne_fresca.head()
# Out:
#              Age         Species
# Case Number
# 2018.06.25    57      White shark
# 2018.06.18    11              NaN
# 2018.06.09    48              NaN
# 2018.06.08   NaN        2 m shark
# 2018.06.04   NaN  Tiger shark, 3m

# %%
carne_fresca.groupby(["Age"]).count()
# Out:
#          Species
# Age
#                 1
#                 0
#  28             1
#  30             1
#  43             1
# ...           ...
# mid-20s         1
# mid-30s         0
# teen            1
# young           0
#                 1
#
# [157 rows x 1 columns]

# %%
#remover linhas que tem NaN

print(carne_fresca[(carne_fresca["Age"] != "NaN") | (carne_fresca["Species "] != "NaN")])
# Out:
#              Age         Species
# Case Number
# 2018.06.25    57      White shark
# 2018.06.18    11              NaN
# 2018.06.09    48              NaN
# 2018.06.08   NaN        2 m shark
# 2018.06.04   NaN  Tiger shark, 3m
# ...          ...              ...
# NaN          NaN              NaN
# NaN          NaN              NaN
# NaN          NaN              NaN
# NaN          NaN              NaN
# xx           NaN              NaN
#
# [25723 rows x 2 columns]

# %%
#sort first by species, then by age

carne_fresca.sort_values("Species ", "Age")
# Out:
# /var/folders/x0/vvs34nw54z947ssjn9mkjw_00000gn/T/ipykernel_95424/1210207388.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.sort_values except for the argument 'by' will be keyword-only
#   carne_fresca.sort_values("Species ", "Age")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     545         try:
# --> 546             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     547         except KeyError:
#
# KeyError: 'Age'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/x0/vvs34nw54z947ssjn9mkjw_00000gn/T/ipykernel_95424/1210207388.py in <module>
# ----> 1 carne_fresca.sort_values("Species ", "Age")
#
# ...

# %%
print(bite['Species '].values)
# Out:
# ['White shark' nan nan ... nan nan nan]

# %%
#tentar identificar as categorias para consider aceitaveis
print(bite['Species '])
# Out:
# Case Number
# 2018.06.25        White shark
# 2018.06.18                NaN
# 2018.06.09                NaN
# 2018.06.08          2 m shark
# 2018.06.04    Tiger shark, 3m
#                    ...
# NaN                       NaN
# NaN                       NaN
# NaN                       NaN
# NaN                       NaN
# xx                        NaN
# Name: Species , Length: 25723, dtype: object

# %%
#definir rotulos de especies aceitaveis
accepted_species = pd.dataframe['White shark', 'Tiger shark'

# %%
#identificar quais especies nao se encontram na lista pre-aprovada 

inconsistent_species = set(carne_fresca['Species ']).difference(categories[...])
print(inconsistent_species)

#get and print rows with inconsistent categories
inconsistent_rows = carne_fresca['Species '].isin(accepted_species)
